# %% [markdown]
# # Classification de documents : prise en main des outils
#
# Le but de ce TP est de classer des documents textuels... Dans un premier temps, nous allons vérifier le bon fonctionnement des outils sur des données jouets puis appliquer les concepts sur des données réelles.
#
#
# ## Conception de la chaine de traitement
# Pour rappel, une chaine de traitement de documents classique est composée des étapes suivantes:
# 1. Lecture des données et importation
#     - Dans le cadre de nos TP, nous faisons l'hypothèse que le corpus tient en mémoire... Si ce n'est pas le cas, il faut alors ajouter des structures de données avec des buffers (*data-reader*), bien plus complexes à mettre en place.
#     - Le plus grand piège concerne l'encodage des données. Dans le TP... Pas (ou peu) de problème. Dans la vraie vie: il faut faire attention à toujours maitriser les formats d'entrée et de sortie.
# 1. Traitement des données brutes paramétrique. Chaque traitement doit être activable ou desactivable + paramétrable si besoin.
#     - Enlever les informations *inutiles* : chiffre, ponctuations, majuscules, etc... <BR>
#     **L'utilité dépend de l'application!**
#     - Segmenter en mots (=*Tokenization*)
#     - Elimination des stop-words
#     - Stemming/lemmatisation (racinisation)
#     - Byte-pair encoding pour trouver les mots composés (e.g. Sorbonne Université, Ville de Paris, Premier Ministre, etc...)
# 1. Traitement des données numériques
#     - Normalisation *term-frequency* / binarisation
#     - Normalisation *inverse document frequency*
#     - Elimination des mots rares, des mots trop fréquents
#     - Construction de critère de séparabilité pour éliminer des mots etc...
# 1. Apprentissage d'un classifieur
#     - Choix du type de classifieur
#     - Réglage des paramètres du classifieur (régularisation, etc...)
#
# ## Exploitation de la chaine de traitement
#
# On appelle cette étape la réalisation d'une campagne d'expériences: c'est le point clé que nous voulons traviller en TAL cette année.
# 1. Il est impossible de tester toutes les combinaisons par rapport aux propositions ci-dessus... Il faut donc en éliminer un certain nombre.
#     - En discutant avec les experts métiers
#     - En faisant des tests préliminaires
# 1. Après ce premier filtrage, il faut:
#     - Choisir une évaluation fiable et pas trop lente (validation croisée, leave-one-out, split apprentissage/test simple)
#     - Lancer des expériences en grand
#         - = *grid-search*
#         - parallèliser sur plusieurs machines
#         - savoir lancer sur un serveur et se déconnecter
# 1. Collecter et analyser les résultats
#
#
# ## Inférence
#
# L'inférence est ensuite très classique: la chaine de traitement optimale est apte à traiter de nouveaux documents
#
# # Etape 1: charger les données

# %%
import numpy as np
import matplotlib.pyplot as plt

import codecs
import re
import os.path

# %%
# Chargement des données:
def load_pres(fname):
    alltxts = []
    alllabs = []
    s=codecs.open(fname, 'r','utf-8') # pour régler le codage
    while True:
        txt = s.readline()
        if(len(txt))<5:
            break
        #
        lab = re.sub(r"<[0-9]*:[0-9]*:(.)>.*","\\1",txt)
        txt = re.sub(r"<[0-9]*:[0-9]*:.>(.*)","\\1",txt)
        if lab.count('M') >0:
            alllabs.append(-1)
        else: 
            alllabs.append(1)
        alltxts.append(txt)
    return alltxts,alllabs

# %%
import string
import unicodedata
import nltk
from   nltk.stem    import WordNetLemmatizer
from nltk.stem.snowball import FrenchStemmer

class preprocessing():
    """
    All functions related to preprocessing
    """
    
    def __init__(self) -> None:   
        pass

    def do_all(self, text : tuple, my_punc : string = '\n\r\t') -> tuple:
        """
        Apply all the preprocessing function in one loop (to save time) (Except lemmatisation)
        """
        punc = string.punctuation  
        punc += my_punc
        return [(unicodedata.normalize('NFD'
                , re.sub('[0-9]+', ''
                , line.lower()
                .translate(str.maketrans(punc, ' ' * len(punc)))))
                .encode('ascii', 'ignore').decode("utf-8")
                .replace("  ", " ")
                .strip()
                ,pol) for line,pol in text]
    
    def remove_maj(self, text : tuple) -> tuple :
        """
        Return a tuple of text in lower case
        """
        return [(line.lower(),pol) for line,pol in text]

    def remove_punctuation(self, text  : tuple, my_punc : string = '\n\r\t') -> tuple :
        """
        Return a tuple of text without punctuation
        """
        punc = string.punctuation  
        punc += my_punc
        return [(line.translate(str.maketrans(punc, ' ' * len(punc))),pol) for line, pol in text]

    def remove_numbers(self, text : tuple) -> tuple :
        """
        Return a tuple of text without numbers
        """
        return [(re.sub('[0-9]+', '', line),pol) for line,pol in text]

    def remove_non_normalized_char(self, text : tuple) -> tuple :
        """
        Return a tuple of text without non normalized char
        """
        return [(unicodedata.normalize('NFD', line).encode('ascii', 'ignore').decode("utf-8"),pol) for line,pol in text]

    def get_line(self, text : tuple, sep : str = '\n', n : int = 0) -> tuple :
        """
        Returns a text list with the n-th line 
            - sep : string to recognize a new line
            - n : Integer of the line (0 = first, -1 = last)
        """
        return [(line.strip().split(sep)[n], pol) for line,pol in text]

    def remove_space(self, text : tuple) -> tuple:
        """
        Return a tuple of text without supernumerary space
        """
        return  [(line.replace("  ", " ").strip(), pol) for line,pol in text]

    def lemmatisation(self, text : tuple) -> tuple :
        """
        Return a lemmatized list 
        """
        # Téléchargez le stemmer français
        nltk.download('stopwords')
        nltk.download('punkt')
        nltk.download('rslp')

        # Créez un objet stemmer français
        stemmer = FrenchStemmer()
        l_words = [(nltk.word_tokenize(line),pol) for line,pol in text]
        stemmed_words = [([stemmer.stem(word) for word in line],pol) for line,pol in l_words]
        # print(stemmed_words)
        return [(" ".join(line),pol) for line,pol in stemmed_words]

# %%
president_path_train = "./ressources/AFDpresidentutf8/corpus.tache1.learn.utf8"
president_path_test = "./ressources/AFDpresidentutf8/corpus.tache1.test.utf8"

# Parsing
palltxts_train, palllabs_train = load_pres(president_path_train)
palltxts_test, palllabs_test = load_pres(president_path_test)

# Zip in tupe
p_train = list(zip(palltxts_train, palllabs_train))
p_test = list(zip(palltxts_test, palllabs_test))

# %%
def load_movies(path2data): # 1 classe par répertoire
    alltxts = [] # init vide
    labs = []
    cpt = 0
    for cl in os.listdir(path2data): # parcours des fichiers d'un répertoire
        for f in os.listdir(path2data+cl):
            txt = open(path2data+cl+'/'+f).read()
            alltxts.append(txt)
            labs.append(cpt)
        cpt+=1 # chg répertoire = cht classe
        
    return alltxts,labs

# %%
# Faire la même pour les movies
# TODO

# %%
# print(len(alltxts),len(alllabs))
# print(alltxts[0])
# print(alllabs[0])
# print(alltxts[-1])
# print(alllabs[-1])

# %% [markdown]
# # Transformation paramétrique du texte
#
# Vous devez tester, par exemple, les cas suivants:
# - transformation en minuscule ou pas
# - suppression de la ponctuation
# - transformation des mots entièrement en majuscule en marqueurs spécifiques
# - suppression des chiffres ou pas
# - conservation d'une partie du texte seulement (seulement la première ligne = titre, seulement la dernière ligne = résumé, ...)
# - stemming
# - ...
#
#
# Vérifier systématiquement sur un exemple ou deux le bon fonctionnement des méthodes sur deux documents (au moins un de chaque classe).

# %%
# Testing preprocessing functions

preprocessor = preprocessing()

# President
two_line = p_train[0:2]
two_line[0] = ('   999' + two_line[0][0], two_line[0][1])
print("Normal text :")
print(two_line)

print("\nMinuscule :")
print(preprocessor.remove_maj(two_line))

print("\nNumbers :")
print(preprocessor.remove_numbers(two_line))

print("\nNormalized char :")
print(preprocessor.remove_non_normalized_char(two_line))

print("\npunctuation :")
print(preprocessor.remove_punctuation(two_line))

print("\nSpace :")
print(preprocessor.remove_space(two_line))

print("\nLemmatisation :")
print(preprocessor.lemmatisation(two_line))

print("\nGet line :") # Here as the separator use is a space it will get the last word
print(preprocessor.get_line(two_line, sep = ' ', n = -1))

print("\nAll :")
print(preprocessor.do_all(two_line))
# Out:
# Normal text :
# [("   999 Quand je dis chers amis, il ne s'agit pas là d'une formule diplomatique, mais de l'expression de ce que je ressens.\r\n", 1), (" D'abord merci de cet exceptionnel accueil que les Congolais, les Brazavillois, nous ont réservé cet après-midi.\r\n", 1)]
#
# Minuscule :
# [("   999 quand je dis chers amis, il ne s'agit pas là d'une formule diplomatique, mais de l'expression de ce que je ressens.\r\n", 1), (" d'abord merci de cet exceptionnel accueil que les congolais, les brazavillois, nous ont réservé cet après-midi.\r\n", 1)]
#
# Numbers :
# [("    Quand je dis chers amis, il ne s'agit pas là d'une formule diplomatique, mais de l'expression de ce que je ressens.\r\n", 1), (" D'abord merci de cet exceptionnel accueil que les Congolais, les Brazavillois, nous ont réservé cet après-midi.\r\n", 1)]
#
# Normalized char :
# [("   999 Quand je dis chers amis, il ne s'agit pas la d'une formule diplomatique, mais de l'expression de ce que je ressens.\r\n", 1), (" D'abord merci de cet exceptionnel accueil que les Congolais, les Brazavillois, nous ont reserve cet apres-midi.\r\n", 1)]
#
# punctuation :
# [('   999 Quand je dis chers amis  il ne s agit pas là d une formule diplomatique  mais de l expression de ce que je ressens   ', 1), (' D abord merci de cet exceptionnel accueil que les Congolais  les Brazavillois  nous ont réservé cet après midi   ', 1)]
#
# Space :
# [("999 Quand je dis chers amis, il ne s'agit pas là d'une formule diplomatique, mais de l'expression de ce que je ressens.", 1), ("D'abord merci de cet exceptionnel accueil que les Congolais, les Brazavillois, nous ont réservé cet après-midi.", 1)]
#
# Lemmatisation :
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Ju'\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Ju'\AppData\Roaming\nltk_data...
# [("999 quand je dis cher amis , il ne s'ag pas là d'un formul diplomat , mais de l'express de ce que je ressen .", 1), ("d'abord merc de cet exceptionnel accueil que le congol , le brazavillois , nous ont réserv cet après-mid .", 1)]
#
# Get line :
# [('ressens.', 1), ('après-midi.', 1)]
#
# All :
# [('quand je dis chers amis il ne s agit pas la d une formule diplomatique mais de l expression de ce que je ressens', 1), ('d abord merci de cet exceptionnel accueil que les congolais les brazavillois nous ont reserve cet apres midi', 1)]
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package rslp to
# [nltk_data]     C:\Users\Ju'\AppData\Roaming\nltk_data...
# [nltk_data]   Package rslp is already up-to-date!

# %%
# Preprocessing Text

# President 
## Train
p_train = preprocessor.do_all(p_train)
# p_train = preprocessor.lemmatisation(p_train)

## Test
p_test = preprocessor.do_all(p_test)
# p_test = preprocessor.lemmatisation(p_test)

# Movie
# TODO

# %% [markdown]
# # Extraction du vocabulaire
#
# Exploration préliminaire des jeux de données.
#
# - Quelle est la taille d'origine du vocabulaire?
# - Que reste-t-il si on ne garde que les 100 mots les plus fréquents? [word cloud]
# - Quels sont les 100 mots dont la fréquence documentaire est la plus grande? [word cloud]
# - Quels sont les 100 mots les plus discriminants au sens de odds ratio? [word cloud]
# - Quelle est la distribution d'apparition des mots (Zipf)
# - Quels sont les 100 bigrammes/trigrammes les plus fréquents?

# %%
import sklearn
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_selection import chi2
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from collections import Counter
import math
from scipy import special


class voc_extracting():

    def __init__(self) -> None:
        self.vectorizer = CountVectorizer()


    def get_size(self, text : tuple) -> int :
        """
        Return the size of a vocabulary
        """
        corpus = [line for line,pol in text]
        self.vectorizer.fit_transform(corpus)
        return len(self.vectorizer.get_feature_names())

    def get_zipf_distribution(self, text : tuple, n : int = 100) -> list :
        vectorizer = CountVectorizer()
        corpus = [line for line,pol in text]
        X = vectorizer.fit_transform(corpus)
        sum_words = X.sum(axis=0) 
        words_freq = [(word, sum_words[0, idx]) for word, idx in vectorizer.vocabulary_.items()]
        words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
        max_f = words_freq[0][1]
        a = 2. #  distribution parameter
        return [w for w,f in words_freq[:n]]

    def get_tf_idf(self, text : tuple, n : int = 100) -> list :
        """
        Return the list of n words the most frequent according to TF-IDF
        """
        # self.get_most_freq_word(text, n)
        # tot_word = sum([f for w,f in self.wc.most_common() if len(w) > 1])
        # tf_list = [(w,f/tot_word) for w,f in self.wc.most_common() if len(w) > 1]
        # tf_list = sorted(tf_list, key=lambda x: x[0], reverse=False)

        corpus = [line for line,pol in text]
        vectorizer = TfidfVectorizer()
        X = vectorizer.fit_transform(corpus)
        # feature_names = vectorizer.get_feature_names()
        # nb_doc = len(text)
        # IDF = np.asarray(nb_doc/X.sum(axis=0)).ravel()
        # IDF_log = [math.log(x) for x in IDF]
        # scores = [(tf[0],tf[1]-idf) for tf,idf in zip(tf_list,IDF_log)]


        scores = zip(vectorizer.get_feature_names(),
                 np.asarray(X.sum(axis=0)).ravel())  # donne le même résultat que la formule tf-idf

        sorted_scores = sorted(scores, key=lambda x: x[1], reverse=True)
        return [w[0] for w in sorted_scores[:n]]
    
    def get_most_freq_word(self, text : tuple, n : int = 100) -> list :
        """
        Return the list of n words the most frequent
        """
        vectorizer = CountVectorizer()
        corpus = [line for line,pol in text]
        X = vectorizer.fit_transform(corpus)
        sum_words = X.sum(axis=0) 
        words_freq = [(word, sum_words[0, idx]) for word, idx in vectorizer.vocabulary_.items()]
        words_freq = sorted(words_freq, key = lambda x: x[1], reverse=True)
        return [w for w,f in words_freq[:n]]

    def word_cloud(self, text : tuple, stop_word : list = None) -> None :
        """
        Display word cloud
        """
        corpus = [line for line,pol in text]
        corpus = ' '.join(corpus)
        wordcloud = WordCloud(stopwords = stop_word).generate(corpus)
        plt.imshow(wordcloud, interpolation="bilinear")
        WordCloud()

    def get_odd(self, text : tuple, n : int = 100) -> list :
        corpus = [ line for line,pol in text]
        vectorizer = CountVectorizer()
        X = vectorizer.fit_transform(corpus)
        features = vectorizer.get_feature_names()
        chi2score = chi2(X, y)[0]
        # scores = list(zip(features, chi2score))


        # oddsratios, pvals = list(map(lambda x: list(x), zip(*[f_classif(X.toarray(), y) for y in [0,1]])))
        # sorted_oddsratios = sorted(zip(X_features, oddsratios, pvals), key=lambda x: x[1], reverse=True)
        # return sorted_oddsratios[:n]

# %%
def get_odd_ratios_discr_words(self, text : tuple):
    """
    Return a list of discriminant words
    """
    vectorizer = CountVectorizer()
    corpus = [line for line,pol in text]
    X = vectorizer.fit_transform(corpus)

    pos1 = [i for i, (line, pol) in enumerate(text) if pol == 1]
    pos2 = [i for i, (line, pol) in enumerate(text) if pol == -1]
    X_class1 = X[pos1,:]
    X_class2 = X[pos2,:]

    sum_words1 = X_class1.sum(axis=0)
    sum_words2 = X_class2.sum(axis=0)

    n_voc = len(vectorizer.vocabulary_)
    words_freq1 = [(word, sum_words1[0, idx]) for word, idx in vectorizer.vocabulary_.items()]
    words_freq2 = [(word, sum_words2[0, idx]) for word, idx in vectorizer.vocabulary_.items()]


    odd_ratios = [(word, get_odd_ratio(words_freq1[idx][1]/n_voc, words_freq2[idx][1]/n_voc)) for word, idx in vectorizer.vocabulary_.items()]
       
    odd_ratios = sorted(odd_ratios, key = lambda x: x[1], reverse=True)
    return [w for w,f in words_freq[:n]]

# %%
def get_odd_ratio(p : float, q : float):
    """
    Calculate odd ratios from the frequencies p and q
    """
    if p not in [0,1] and q not in [0,1]:
        OR = (p*(1-q)) / (q*(1-p))
        #OR = np.log(p*(1-q)) - np.log(q*(1-p))
        return OR
    else:
        return 0 #A changer peut etre

# %%
vectorizer = CountVectorizer()
corpus = [line for line,pol in p_train]
X = vectorizer.fit_transform(corpus)

#transform

pos1 = [i for i, (line, pol) in enumerate(p_train) if pol == 1]
pos2 = [i for i, (line, pol) in enumerate(p_train) if pol == -1]
#X_class1 = X[pos1,:]
#X_class2 = X[pos2,:]
corpus1 = [line for line,pol in [p_train[p1] for p1 in pos1]]
corpus2 = [line for line,pol in [p_train[p1] for p1 in pos2]]
X_class1 = vectorizer.transform(corpus1)
X_class2 = vectorizer.transform(corpus2)

print(X_class1.shape)
print(X_class2.shape)

sum_words1 = X_class1.sum(axis=0)
sum_words2 = X_class2.sum(axis=0)

n_voc = len(vectorizer.vocabulary_)
words_freq1 = [(word, sum_words1[0, idx]) for word, idx in vectorizer.vocabulary_.items()]
words_freq2 = [(word, sum_words2[0, idx]) for word, idx in vectorizer.vocabulary_.items()]


odd_ratios = [(word, get_odd_ratio(words_freq1[idx][1]/n_voc, words_freq2[idx][1]/n_voc)) for word, idx in vectorizer.vocabulary_.items()]
odd_ratios = sorted(odd_ratios, key = lambda x: x[1], reverse=True)
odd_ratios
# Out:
# (49890, 27054)
# (7523, 27054)
# [('accueillie', 359.70691786209227),
#  ('assouplie', 192.35092878680712),
#  ('blindee', 163.98196422594918),
#  ('ajustements', 146.78675486844062),
#  ('attendiez', 136.68207147633552),
#  ('mondiales', 104.39747680890538),
#  ('changeraient', 97.18618070808978),
#  ('evoquaient', 93.31734727940359),
#  ('achetant', 88.28391307572498),
#  ('antillo', 88.06317199300568),
#  ('arawaks', 79.68933885222062),
#  ('connaissant', 79.45820939916717),
#  ('clair', 76.21128326784788),
#  ('anterieure', 75.20571555654398),
#  ('dan', 75.20571555654398),
#  ('anormale', 73.39066448639808),
#  ('anticipees', 73.19480375078759),
#  ('agrandi', 72.23275829948956),
#  ('appropriees', 71.36935196195004),
#  ('cantons', 71.18419004558424),
#  ('alternative', 70.358921007654),
#  ('battus', 70.17899495997627),
#  ('bergere', 69.17387437465258),
#  ('connexion', 68.16882828133106),
#  ('agents', 67.66034495632047),
#  ('adaptabilite', 66.15895953757226),
#  ('acharnement', 64.8042339832869),
#  ('antenne', 64.299487484216),
#  ('aggrave', 63.14471490496832),
#  ('apprehendons', 60.131140253389646),
#  ('deviendront', 59.12676421559548),
#  ('decent', 59.12676421559548),
#  ('carnage', 59.12676421559548),
#  ('casseurs', 58.00472970448687),
#  ('complement', 57.11823535948439),
#  ('charm', 57.11823535948439),
#  ('apprenais', 56.22863929923538),
#  ('caracterisent', 56.11408252463145),
#  ('considerant', 56.11408252463145),
#  ('bourgeoises', 55.110004074224975),
#  ('citadelle', 54.106),
#  ('derobe', 53.10207029369283),
#  ('affranchie', 52.700656796170534),
#  ('aveugles', 52.098214947040965),
#  ('avare', 51.09443395178313),
#  ('constructives', 51.09443395178313),
#  ('condamnation', 50.090727299659314),
#  ('constituee', 50.090727299659314),
#  ('anterieures', 50.090727299659314),
#  ('caravelle', 49.17450660335361),
#  ('carbonnier', 49.08709498241066),
#  ('cenacle', 48.16737146672602),
#  ('catastrophes', 48.083536991779596),
#  ('composites', 48.083536991779596),
#  ('boheme', 48.083536991779596),
#  ('cassure', 48.083536991779596),
#  ('allait', 47.66385993545754),
#  ('boucle', 47.08005331950975),
#  ('constitues', 46.076643957345965),
#  ('auteurs', 46.076643957345965),
#  ('afficher', 45.220661985957875),
#  ('deux', 45.073308897034316),
#  ('adaptation', 45.073308897034316),
#  ('biodiversite', 45.073308897034316),
#  ('calanque', 45.041395348837206),
#  ('fresques', 44.14032485351924),
#  ('citoyens', 44.0700481303221),
#  ('capitalistes', 44.0700481303221),
#  ('entrevoyait', 44.0700481303221),
#  ('bouts', 44.0700481303221),
#  ('concours', 43.20122562674095),
#  ('deuils', 43.06686164895783),
#  ('circonspection', 43.06686164895783),
#  ('allons', 43.02818746724564),
#  ('confonde', 42.864740399613765),
#  ('comte', 42.06374944469125),
#  ('affichent', 42.06374944469125),
#  ('deplacent', 42.06374944469125),
#  ('convaincante', 42.06374944469125),
#  ('collectivisation', 42.06374944469125),
#  ('apprenti', 41.62463386600423),
#  ('araser', 41.62463386600423),
#  ('comtes', 41.51904938730042),
#  ('collectes', 41.121607593059466),
#  ('charte', 41.06071150927331),
#  ('aune', 41.06071150927331),
#  ('batirez', 41.06071150927331),
#  ('devolu', 41.06071150927331),
#  ('decimee', 41.06071150927331),
#  ('cenotaphe', 40.846353779890094),
#  ('acquerront', 40.73795180722892),
#  ('acheverait', 40.18372850882122),
#  ('annuler', 40.1156669385334),
#  ('achetez', 40.1156669385334),
#  ('defileront', 40.1156669385334),
#  ('collectifs', 40.0577478344562),
#  ('consideration', 40.0577478344562),
#  ('damocles', 40.0577478344562),
#  ('coevolution', 40.0577478344562),
#  ('adduction', 40.0577478344562),
#  ('applicable', 39.83749767959904),
#  ('anormal', 39.10987544483985),
#  ('baisser', 39.054858411993344),
#  ('anticipe', 39.054858411993344),
#  ('estimeraient', 39.054858411993344),
#  ('aire', 38.49270574260366),
#  ('berge', 38.461860153897625),
#  ('arbitrer', 38.15657015590201),
#  ('biographies', 38.104233078804945),
#  ('affection', 38.05204323363933),
#  ('annoncer', 38.05204323363933),
#  ('assistante', 38.05204323363933),
#  ('festivites', 38.05204323363933),
#  ('bievre', 38.05204323363933),
#  ('appelez', 37.93044039309577),
#  ('cautions', 37.856115536365664),
#  ('assistant', 37.79025376150909),
#  ('bortois', 37.60146780829533),
#  ('belgradois', 37.098739807264636),
#  ('airbus', 37.04930229115001),
#  ('blame', 37.04930229115001),
#  ('catholicisme', 37.04930229115001),
#  ('impressionnante', 37.04930229115001),
#  ('demotivant', 37.04930229115001),
#  ('avivee', 37.04930229115001),
#  ('confererait', 36.476266468732604),
#  ('acquitte', 36.4370855505526),
#  ('disposant', 36.046635576282476),
#  ('concluait', 36.046635576282476),
#  ('deblayant', 36.046635576282476),
#  ('calmes', 36.046635576282476),
#  ('assumeront', 36.046635576282476),
#  ('affiliation', 36.046635576282476),
#  ('attaquerions', 36.046635576282476),
#  ('exhaustif', 36.046635576282476),
#  ('boue', 36.046635576282476),
#  ('achemine', 35.96595816590935),
#  ('bilans', 35.08820041506077),
#  ('jets', 35.04404308079499),
#  ('alignerons', 34.830160988393864),
#  ('decouverte', 34.4607250194798),
#  ('anodins', 34.15028037383178),
#  ('ancrer', 34.12488869100624),
#  ('boutros', 34.08315422811828),
#  ('apportions', 34.08315422811828),
#  ('abatte', 34.08156120814867),
#  ('commercialisation', 34.04152479644707),
#  ('charme', 34.04152479644707),
#  ('centralise', 34.04152479644707),
#  ('complainte', 34.04152479644707),
#  ('contribuerent', 34.04152479644707),
#  ('amendee', 34.04152479644707),
#  ('borges', 34.04152479644707),
#  ('arretait', 33.66177563150074),
#  ('avignonais', 33.0782570031125),
#  ('engagements', 33.03908071499944),
#  ('destabilisation', 33.03908071499944),
#  ('composerent', 33.03908071499944),
#  ('enormes', 33.03908071499944),
#  ('complicites', 33.03908071499944),
#  ('bousculees', 32.575864240987066),
#  ('abattre', 32.446080795340734),
#  ('bidault', 32.42350822853305),
#  ('arabes', 32.399721448467965),
#  ('assortie', 32.29614150309725),
#  ('convenaient', 32.07350870692849),
#  ('cafes', 32.07350870692849),
#  ('couronne', 32.03671082821405),
#  ('convainquants', 32.03671082821405),
#  ('betteraves', 32.03671082821405),
#  ('battit', 32.03671082821405),
#  ('conserverons', 32.03671082821405),
#  ('commentees', 32.03671082821405),
#  ('bacteriennes', 31.895031009767152),
#  ('ancres', 31.879716100112063),
#  ('acharnes', 31.71034623414681),
#  ('commerciale', 31.03441512785405),
#  ('camp', 31.03441512785405),
#  ('dangereuse', 31.03441512785405),
#  ('evitent', 31.03441512785405),
#  ('barbares', 31.03441512785405),
#  ('bugeaud', 31.03441512785405),
#  ('cyrenaique', 31.03441512785405),
#  ('convergentes', 31.03441512785405),
#  ('consuls', 31.03441512785405),
#  ('astronomie', 30.631871705730624),
#  ('andalousie', 30.566665431778606),
#  ('blason', 30.566665431778606),
#  ('concue', 30.432333197344516),
#  ('adaptons', 30.381409423383946),
#  ('ambiguites', 30.29233870967742),
#  ('contemplative', 30.161685994647634),
#  ('assignee', 30.06445876861525),
#  ('choisissant', 30.06445876861525),
#  ('depit', 30.032193605683837),
#  ('cheres', 30.032193605683837),
#  ('enseigner', 30.032193605683837),
#  ('cumulent', 30.032193605683837),
#  ('bioethique', 30.032193605683837),
#  ('approfondissons', 30.032193605683837),
#  ('epiphanie', 30.032193605683837),
#  ('demanderait', 30.032193605683837),
#  ('appliqueront', 30.032193605683837),
#  ('boursier', 30.032193605683837),
#  ('expliciter', 30.032193605683837),
#  ('cape', 29.95949451774763),
#  ('chretienne', 29.562289312835706),
#  ('competitifs', 29.562289312835706),
#  ('arrangeait', 29.18125),
#  ('allouees', 29.115059836707307),
#  ('attends', 29.090332628768497),
#  ('devons', 29.060157060305222),
#  ('difficultes', 29.030046253469006),
#  ('anime', 29.030046253469006),
#  ('collections', 29.030046253469006),
#  ('autosuffisance', 29.030046253469006),
#  ('aborderai', 29.030046253469006),
#  ('discerner', 29.030046253469006),
#  ('fronton', 29.030046253469006),
#  ('appelee', 29.030046253469006),
#  ('confiscatoire', 29.030046253469006),
#  ('decouvrons', 29.030046253469006),
#  ('derangeantes', 29.030046253469006),
#  ('complements', 29.030046253469006),
#  ('evaluations', 29.030046253469006),
#  ('cacophonie', 29.030046253469006),
#  ('atteinte', 28.948762541806026),
#  ('avouant', 28.754894690002967),
#  ('batirait', 28.746661216602877),
#  ('allees', 28.616369710467705),
#  ('catechisme', 28.58988758315685),
#  ('ambitieuse', 28.55806200688965),
#  ('assistes', 28.55806200688965),
#  ('alsace', 28.364296054340965),
#  ('biennio', 28.112241110533738),
#  ('ardemment', 28.056004148455436),
#  ('cassation', 28.056004148455436),
#  ('chef', 28.02797306297639),
#  ('dependent', 28.02797306297639),
#  ('direct', 28.02797306297639),
#  ('diffusees', 28.02797306297639),
#  ('cannee', 28.02797306297639),
#  ('aneantir', 28.02797306297639),
#  ('biochimie', 28.02797306297639),
#  ('dirigeantes', 28.02797306297639),
#  ('architectural', 27.938406093256553),
#  ('cahier', 27.938406093256553),
#  ('alsaciens', 27.74873011753365),
#  ('attele', 27.615448551786315),
#  ('comptent', 27.55398348086966),
#  ('deciderez', 27.55398348086966),
#  ('angers', 27.55398348086966),
#  ('altran', 27.55398348086966),
#  ('evite', 27.025974025974026),
#  ('centres', 27.025974025974026),
#  ('charges', 27.025974025974026),
#  ('cohabitation', 27.025974025974026),
#  ('centramericain', 27.025974025974026),
#  ('completant', 27.025974025974026),
#  ('delmas', 27.025974025974026),
#  ('abois', 27.025974025974026),
#  ('barbare', 27.025974025974026),
#  ('bort', 27.025974025974026),
#  ('engourdissement', 27.025974025974026),
#  ('ancrent', 26.89326257915978),
#  ('agadir', 26.742789352710016),
#  ('aggraverait', 26.742789352710016),
#  ('attendait', 26.65075292805354),
#  ('abolirait', 26.56508920471727),
#  ('cilicie', 26.550053701714752),
#  ('annexes', 26.550053701714752),
#  ('antibiotique', 26.44878338208857),
#  ('alpes', 26.096474953617808),
#  ('allee', 26.038781907747424),
#  ('considerations', 26.02404913423117),
#  ('descend', 26.02404913423117),
#  ('charabia', 26.02404913423117),
#  ('bit', 26.02404913423117),
#  ('demontrant', 26.02404913423117),
#  ('endurer', 26.02404913423117),
#  ('demenagements', 26.02404913423117),
#  ('deranger', 26.02404913423117),
#  ('concoivent', 26.02404913423117),
#  ('individualisme', 26.02404913423117),
#  ('efficient', 26.02404913423117),
#  ('cristallographe', 26.02404913423117),
#  ('apprendre', 25.88563608413633),
#  ('abondent', 25.764462632841962),
#  ('comparables', 25.737072320865924),
#  ('besancon', 25.737072320865924),
#  ('andes', 25.711269727673358),
#  ('assis', 25.546272636373732),
#  ('bacteriologique', 25.546272636373732),
#  ('borneo', 25.42718157080553),
#  ('approuvent', 25.40188301579065),
#  ('appuyer', 25.13380909901873),
#  ('appuiera', 25.13380909901873),
#  ('anonyme', 25.111404062534813),
#  ('brillantes', 25.044437861057624),
#  ('acceptes', 25.03847199819948),
#  ('humain', 25.022198379518297),
#  ('construit', 25.022198379518297),
#  ('enorgueillir', 25.022198379518297),
#  ('adaptations', 25.022198379518297),
#  ('courte', 25.022198379518297),
#  ('feuille', 25.022198379518297),
#  ('cambodgien', 25.022198379518297),
#  ('biomasse', 25.022198379518297),
#  ('birmanie', 25.022198379518297),
#  ('contagion', 25.022198379518297),
#  ('leverons', 25.022198379518297),
#  ('epaulee', 25.022198379518297),
#  ('abattues', 24.838555732644778),
#  ('appuis', 24.666433786493084),
#  ('construisirent', 24.54264025180522),
#  ('complications', 24.54264025180522),
#  ('chequier', 24.54264025180522),
#  ('appliquant', 24.33366101569165),
#  ('avenirs', 24.33366101569165),
#  ('abonde', 24.181719372703274),
#  ('apprentissages', 24.104105910870782),
#  ('autriche', 24.061374249499668),
#  ('cinquantieme', 24.040879804487886),
#  ('chemins', 24.0204217536071),
#  ('circonstance', 24.0204217536071),
#  ('mesurons', 24.0204217536071),
#  ('depasserait', 24.0204217536071),
#  ('besogne', 24.0204217536071),
#  ('cibles', 24.0204217536071),
#  ('arretee', 24.0204217536071),
#  ('assiette', 24.0204217536071),
#  ('clairvoyante', 24.0204217536071),
#  ('indianoceanique', 24.0204217536071),
#  ('cop', 24.0204217536071),
#  ('apporte', 23.72630915761776),
#  ('bombardements', 23.72630915761776),
#  ('absolus', 23.61787983502397),
#  ('attentifs', 23.539156514977595),
#  ('coalitions', 23.391268900088946),
#  ('chargera', 23.391268900088946),
#  ('contractualises', 23.391268900088946),
#  ('boursiers', 23.326749749638367),
#  ('approchera', 23.295597297497956),
#  ('boulogne', 23.295597297497956),
#  ('capital', 23.11279536335265),
#  ('berceau', 23.11279536335265),
#  ('danone', 23.075068615087897),
#  ('dechirures', 23.037470379146914),
#  ('assouvir', 23.037470379146914),
#  ('facon', 23.018719248270504),
#  ('disait', 23.018719248270504),
#  ('demandant', 23.018719248270504),
#  ('financements', 23.018719248270504),
#  ('contamines', 23.018719248270504),
#  ('discriminations', 23.018719248270504),
#  ('prolonges', 23.018719248270504),
#  ('enseignees', 23.018719248270504),
#  ('cajolee', 23.018719248270504),
#  ('desherites', 23.018719248270504),
#  ('deltas', 23.018719248270504),
#  ('berkeley', 23.018719248270504),
#  ('diligenter', 23.018719248270504),
#  ('celeste', 23.018719248270504),
#  ('ecartait', 23.018719248270504),
#  ('convaincants', 23.018719248270504),
#  ('dispensees', 23.018719248270504),
#  ('arsenal', 22.72126287704736),
#  ('anciennement', 22.60576493371071),
#  ('charnelles', 22.53582139286904),
#  ('aviver', 22.53582139286904),
#  ('debordes', 22.53582139286904),
#  ('cubisme', 22.53582139286904),
#  ('atteignant', 22.53582139286904),
#  ('agen', 22.49301753993967),
#  ('allions', 22.439524517087666),
#  ('alderman', 22.386297106014005),
#  ('appliquerait', 22.320137214908215),
#  ('amazonien', 22.320137214908215),
#  ('berne', 22.287339939873064),
#  ('capter', 22.287339939873064),
#  ('aphrodite', 22.259317467444994),
#  ('acheteur', 22.145837464116067),
#  ('decades', 22.051356158292577),
#  ('commencez', 22.042111926127266),
#  ('bonds', 22.034209552017767),
#  ('croient', 22.034209552017767),
#  ('celestes', 22.034209552017767),
#  ('clerges', 22.034209552017767),
#  ('augmentation', 22.01709085528263),
#  ('bas', 22.01709085528263),
#  ('evoluer', 22.01709085528263),
#  ('cataclysmes', 22.01709085528263),
#  ('dira', 22.01709085528263),
#  ('educateurs', 22.01709085528263),
#  ('bilbao', 22.01709085528263),
#  ('garcon', 22.01709085528263),
#  ('complexite', 22.01709085528263),
#  ('defendons', 22.01709085528263),
#  ('consommations', 22.01709085528263),
#  ('ble', 22.01709085528263),
#  ('enrichissant', 22.01709085528263),
#  ('chantee', 22.01709085528263),
#  ('cotterets', 22.01709085528263),
#  ('ardents', 21.88431919642857),
#  ('capitalisme', 21.884141770272773),
#  ('depeuple', 21.81694293024808),
#  ('abaissant', 21.816709482854908),
#  ('affectations', 21.612475277083256),
#  ('efforce', 21.53263485246751),
#  ('dahomey', 21.53263485246751),
#  ('cinquieme', 21.481003451219063),
#  ('brillant', 21.3815487217488),
#  ('coherentes', 21.3815487217488),
#  ('augustins', 21.378050141348016),
#  ('aquarelles', 21.32781734210016),
#  ('besoins', 21.313823278579108),
#  ('analphabetisme', 21.30235725907147),
#  ('causee', 21.279456731482856),
#  ('affaiblie', 21.25365558399083),
#  ('battaient', 21.251506416217225),
#  ('assigne', 21.20387588215526),
#  ('annonciatrice', 21.140703517587937),
#  ('collaborations', 21.046682227409136),
#  ('civiles', 21.03109729009329),
#  ('brigade', 21.03109729009329),
#  ('accrus', 21.03109729009329),
#  ('definie', 21.03109729009329),
#  ('arrachage', 21.03109729009329),
#  ('cahors', 21.03109729009329),
#  ('confronteront', 21.03109729009329),
#  ('aldrovandi', 21.03109729009329),
#  ('divisee', 21.01553656641882),
#  ('dialogues', 21.01553656641882),
#  ('consiste', 21.01553656641882),
#  ('contemporain', 21.01553656641882),
#  ('entrainera', 21.01553656641882),
#  ('couteux', 21.01553656641882),
#  ('accelerent', 21.01553656641882),
#  ('bienvenus', 21.01553656641882),
#  ('calais', 21.01553656641882),
#  ('envisage', 21.01553656641882),
#  ('depassons', 21.01553656641882),
#  ('medecin', 21.01553656641882),
#  ('condamnerons', 21.01553656641882),
#  ('imagee', 21.01553656641882),
#  ('apportait', 21.01553656641882),
#  ('bouffons', 21.01553656641882),
#  ('anormalement', 21.01553656641882),
#  ('arpenter', 20.757222428518382),
#  ('comique', 20.711840545346774),
#  ('arrivions', 20.67490631145412),
#  ('assistees', 20.55928370161649),
#  ('cours', 20.529596860770738),
#  ('approuvee', 20.529596860770738),
#  ('enoncons', 20.529596860770738),
#  ('confrontent', 20.377023672804064),
#  ('civilite', 20.377023672804064),
#  ('anomalies', 20.26556532681699),
#  ('ajouterent', 20.05635055979832),
#  ('anachronique', 20.042231607023787),
#  ('defend', 20.028133560376098),
#  ('couronnant', 20.028133560376098),
#  ('dispose', 20.014056373455652),
#  ('derniers', 20.014056373455652),
#  ('arabe', 20.014056373455652),
#  ('avertissement', 20.014056373455652),
#  ('desservi', 20.014056373455652),
#  ('conservatoire', 20.014056373455652),
#  ('greffe', 20.014056373455652),
#  ('dames', 20.014056373455652),
#  ('basse', 20.014056373455652),
#  ('baptise', 20.014056373455652),
#  ('forgeant', 20.014056373455652),
#  ('horseguards', 20.014056373455652),
#  ('arrachees', 20.014056373455652),
#  ('irrespect', 20.014056373455652),
#  ('declarent', 20.014056373455652),
#  ('automatismes', 20.014056373455652),
#  ('designant', 20.014056373455652),
#  ('argentino', 20.014056373455652),
#  ('assoupir', 19.9800468419059),
#  ('alternees', 19.805979042142692),
#  ('bilingues', 19.804911955514363),
#  ('armement', 19.707464345249125),
#  ('incapable', 19.707464345249125),
#  ('cheveux', 19.707464345249125),
#  ('audits', 19.677059305007813),
#  ('dessineront', 19.66762130879953),
#  ('considerez', 19.58035415970598),
#  ('exempte', 19.52670738478623),
#  ('bienvenue', 19.52670738478623),
#  ('ancre', 19.52670738478623),
#  ('africa', 19.437817258883253),
#  ('contradictoires', 19.302090669829855),
#  ('arriver', 19.265526899507503),
#  ('biosphere', 19.264811929668372),
#  ('consister', 19.264811929668372),
#  ('bloquee', 19.165852202782855),
#  ('assumant', 19.076788651315788),
#  ('alla', 19.076169265033407),
#  ('axes', 19.038004222691413),
#  ('beia', 19.038004222691413),
#  ('chaine', 19.02531832987859),
#  ('pourtour', 19.02531832987859),
#  ('blessees', 19.02531832987859),
#  ('appendice', 19.02531832987859),
#  ('cooperations', 19.01265026817089),
#  ('chomeurs', 19.01265026817089),
#  ('falzone', 19.01265026817089),
#  ('assureront', 19.01265026817089),
#  ('crees', 19.01265026817089),
#  ('correspondent', 19.01265026817089),
#  ('considerees', 19.01265026817089),
#  ('degradations', 19.01265026817089),
#  ('foisonne', 19.01265026817089),
#  ('contraignantes', 19.01265026817089),
#  ('correspondu', 19.01265026817089),
#  ('dependaient', 19.01265026817089),
#  ('gris', 19.01265026817089),
#  ('alertiez', 19.01265026817089),
#  ('crif', 19.01265026817089),
#  ('attaquions', 19.01265026817089),
#  ('acheminent', 19.01265026817089),
#  ('cailloux', 19.01265026817089),
#  ('assumes', 18.94903565821933),
#  ('annonciateur', 18.80047861361237),
#  ('ameliorees', 18.79934393417102),
#  ('attachements', 18.741935827850586),
#  ('additionnelle', 18.694781233526623),
#  ('deluge', 18.54799851742031),
#  ('cicatrices', 18.523966391531253),
#  ('enonce', 18.523966391531253),
#  ('avenues', 18.523966391531253),
#  ('artes', 18.523966391531253),
#  ('brosse', 18.523966391531253),
#  ('applaudir', 18.523966391531253),
#  ('biovision', 18.523966391531253),
#  ('codex', 18.523966391531253),
#  ('ci', 18.51915147004094),
#  ('arrive', 18.459372450114977),
#  ('assument', 18.459372450114977),
#  ('anterieurs', 18.459372450114977),
#  ('altantique', 18.439696530179628),
#  ('almoravides', 18.296671731959524),
#  ('comprendrez', 18.2580499202611),
#  ('antidrogue', 18.055786187633494),
#  ('apercevoir', 18.02265156562292),
#  ('batteries', 18.02265156562292),
#  ('coutent', 18.02265156562292),
#  ('cristal', 18.02265156562292),
#  ('assimilee', 18.01256186046512),
#  ('avons', 18.01131824234354),
#  ('disposait', 18.01131824234354),
#  ('atteindre', 18.01131824234354),
#  ('embarcation', 18.01131824234354),
#  ('caisse', 18.01131824234354),
#  ('dommages', 18.01131824234354),
#  ('caracteristiques', 18.01131824234354),
#  ('certitudes', 18.01131824234354),
#  ('defaire', 18.01131824234354),
#  ('csce', 18.01131824234354),
#  ('dayton', 18.01131824234354),
#  ('altitude', 18.01131824234354),
#  ('favorablement', 18.01131824234354),
#  ('contrarie', 18.01131824234354),
#  ('compartiment', 18.01131824234354),
#  ('boeuf', 18.01131824234354),
#  ('cultivons', 18.01131824234354),
#  ('dorer', 18.01131824234354),
#  ('disponiblite', 18.01131824234354),
#  ('etonnerai', 18.01131824234354),
#  ('coincidant', 18.01131824234354),
#  ('entendrai', 18.01131824234354),
#  ('adamaoua', 18.01131824234354),
#  ('hangar', 18.01131824234354),
#  ('connecte', 18.01131824234354),
#  ('englober', 17.794074046621944),
#  ('appetissantes', 17.732225025975954),
#  ('alchimiste', 17.708698563881242),
#  ('cambodgiens', 17.69938150438873),
#  ('alourdissent', 17.679025514856423),
#  ('afrika', 17.678356883151675),
#  ('argentiere', 17.6541719201958),
#  ('arret', 17.607425871498194),
#  ('akhethetep', 17.564288099743962),
#  ('allient', 17.564288099743962),
#  ('amite', 17.54043201844072),
#  ('certitude', 17.521373848032862),
#  ('compromettront', 17.521373848032862),
#  ('avancions', 17.521373848032862),
#  ('agent', 17.384209098069327),
#  ('comptables', 17.36478779349678),
#  ('confirmes', 17.36478779349678),
#  ('abondamment', 17.36478779349678),
#  ('cumul', 17.36478779349678),
#  ('brutal', 17.36478779349678),
#  ('abattu', 17.352971948812407),
#  ('accumulant', 17.330661940356013),
#  ('deplacees', 17.29155086158977),
#  ('boussole', 17.2284516344477),
#  ('achats', 17.18301978856059),
#  ('ambition', 17.121564245810056),
#  ('absorber', 17.050428269494606),
#  ('complementaires', 17.040317201511897),
#  ('ephemere', 17.030218864570607),
#  ('douleur', 17.020133234641005),
#  ('dejeuner', 17.020133234641005),
#  ('derriere', 17.020133234641005),
#  ('ambitieuses', 17.020133234641005),
#  ('armateur', 17.020133234641005),
#  ('capitaliste', 17.020133234641005),
#  ('chantre', 17.020133234641005),
#  ('ajoutez', 17.020133234641005),
#  ('deracinement', 17.020133234641005),
#  ('bordeaux', 17.010060287753817),
#  ('femme', 17.010060287753817),
#  ('crainte', 17.010060287753817),
#  ('devez', 17.010060287753817),
#  ('aventure', 17.010060287753817),
#  ('instituts', 17.010060287753817),
#  ('eternel', 17.010060287753817),
#  ('commandee', 17.010060287753817),
#  ('franchissent', 17.010060287753817),
#  ('engagiez', 17.010060287753817),
#  ('fidji', 17.010060287753817),
#  ('partiront', 17.010060287753817),
#  ('eprise', 17.010060287753817),
#  ('apportes', 17.010060287753817),
#  ('arctiques', 17.010060287753817),
#  ('emaillent', 17.010060287753817),
#  ('considererait', 17.010060287753817),
#  ('convenables', 17.010060287753817),
#  ('envolerai', 17.010060287753817),
#  ('contructions', 17.010060287753817),
#  ('cineastes', 17.010060287753817),
#  ('antisemites', 16.8663346095231),
#  ('aveuglement', 16.834969719524985),
#  ('beneficiaire', 16.782540212877667),
#  ('animee', 16.780153426907567),
#  ('associatives', 16.724790383616536),
#  ('enserrer', 16.69567471485706),
#  ('concentration', 16.633486187227383),
#  ('acct', 16.62786219733316),
#  ('apprehendes', 16.556928213689485),
#  ('annees', 16.537905735882617),
#  ('duree', 16.537905735882617),
#  ('ceremonies', 16.537905735882617),
#  ('assisterons', 16.537905735882617),
#  ('cholera', 16.537905735882617),
#  ('detruit', 16.518929721327854),
#  ('decourager', 16.518929721327854),
#  ('alcools', 16.518929721327854),
#  ('brises', 16.518929721327854),
#  ('desastreux', 16.518929721327854),
#  ('debarquer', 16.518929721327854),
#  ('abimee', 16.498690880509873),
#  ('aides', 16.488243908933566),
#  ('auxquelles', 16.446818923327896),
#  ('ajustement', 16.417103356004013),
#  ('ancrees', 16.389078498293514),
#  ('attentions', 16.36115534160341),
#  ('americanite', 16.36115534160341),
#  ('condamnant', 16.36115534160341),
#  ('ambigue', 16.32363318971921),
#  ('affermie', 16.30481641147614),
#  ('comparable', 16.28672792619215),
#  ('cycles', 16.28672792619215),
#  ('agregee', 16.28672792619215),
#  ('allege', 16.053416425550857),
#  ('competitivite', 16.035568729158946),
#  ('convivial', 16.035568729158946),
#  ('brandi', 16.035568729158946),
#  ('appuyes', 16.035568729158946),
#  ('beau', 16.02666074205732),
#  ('escorte', 16.02666074205732),
#  ('adeptes', 16.02666074205732),
#  ('cles', 16.01776330397454),
#  ('cooperants', 16.01776330397454),
#  ('amie', 16.01776330397454),
#  ('concentre', 16.01776330397454),
#  ('abandonnent', 16.01776330397454),
#  ('clans', 16.01776330397454),
#  ('assiduite', 16.01776330397454),
#  ('arithmetique', 16.01776330397454),
#  ('contestons', 16.01776330397454),
#  ('difficulte', 16.00887639618315),
#  ('ambitieux', 16.00887639618315),
#  ('engagerai', 16.00887639618315),
#  ('geologiques', 16.00887639618315),
#  ('bouleversements', 16.00887639618315),
#  ('camarades', 16.00887639618315),
#  ('incessant', 16.00887639618315),
#  ('observer', 16.00887639618315),
#  ('familieres', 16.00887639618315),
#  ('enrayer', 16.00887639618315),
#  ('circonscriptions', 16.00887639618315),
#  ('controlent', 16.00887639618315),
#  ('dominees', 16.00887639618315),
#  ('divertir', 16.00887639618315),
#  ('abraham', 16.00887639618315),
#  ('arawak', 16.00887639618315),
#  ('animez', 16.00887639618315),
#  ('evaluant', 16.00887639618315),
#  ('compense', 16.00887639618315),
#  ('dysfonctionnements', 16.00887639618315),
#  ('ebranlant', 16.00887639618315),
#  ('deficience', 16.00887639618315),
#  ('bataillon', 16.00887639618315),
#  ('bornerai', 16.00887639618315),
#  ('arrange', 16.00887639618315),
#  ('degages', 16.00887639618315),
#  ('emanation', 16.00887639618315),
#  ('conjure', 16.00887639618315),
#  ('contemplons', 16.00887639618315),
#  ('cineaste', 16.00887639618315),
#  ('inaugurant', 16.00887639618315),
#  ('marthe', 16.00887639618315),
#  ('bistre', 16.00887639618315),
#  ('ghazni', 16.00887639618315),
#  ('fichte', 16.00887639618315),
#  ('antijuif', 15.885604065432693),
#  ('brevete', 15.881998183573659),
#  ('apporterait', 15.795182519855322),
#  ('anatheme', 15.784428142714233),
#  ('autoroutier', 15.773252724960154),
#  ('appelant', 15.76140687957021),
#  ('cheminots', 15.743506855423028),
#  ('calculateurs', 15.717804154302671),
#  ('ascension', 15.692886850607149),
#  ('angouleme', 15.692190913466879),
#  ('acquerrons', 15.692190913466879),
#  ('achevera', 15.630374042361428),
#  ('chimiotherapie', 15.566765688822873),
#  ('arbitre', 15.545948249043025),
#  ('decorer', 15.545948249043025),
#  ('anecdotes', 15.533306164789565),
#  ('concernant', 15.516633978462792),
#  ('concentres', 15.516633978462792),
#  ('eussent', 15.516633978462792),
#  ('carences', 15.516633978462792),
#  ('emanait', 15.516633978462792),
#  ('epuisants', 15.516633978462792),
#  ('bizet', 15.516633978462792),
#  ('anticipent', 15.493319922156864),
#  ('accrochez', 15.359090909090908),
#  ('confiante', 15.357745853080571),
#  ('cherchais', 15.357745853080571),
#  ('calvados', 15.314551462943708),
#  ('arctique', 15.282202793316783),
#  ('affectives', 15.198488093471026),
#  ('accueilir', 15.198488093471026),
#  ('appliquera', 15.179139872876632),
#  ('aines', 15.079792915308891),
#  ('achoppement', 15.054547478570635),
#  ('anthropologue', 15.046728971962615),
#  ('continuite', 15.023325558147285),
#  ('cuisant', 15.023325558147285),
#  ('cab', 15.023325558147285),
#  ('civile', 15.015541740674957),
#  ('dela', 15.015541740674957),
#  ('braves', 15.015541740674957),
#  ('connexes', 15.015541740674957),
#  ('abimes', 15.015541740674957),
#  ('ames', 15.015541740674957),
#  ('cadets', 15.015541740674957),
#  ('goebbels', 15.015541740674957),
#  ('arbitrale', 15.015541740674957),
#  ('fichage', 15.015541740674957),
#  ('biomedecine', 15.015541740674957),
#  ('apens', 15.015541740674957),
#  ('appui', 15.007766559414181),
#  ('injuste', 15.007766559414181),
#  ('concitoyens', 15.007766559414181),
#  ('charente', 15.007766559414181),
#  ('grandit', 15.007766559414181),
#  ('egrenees', 15.007766559414181),
#  ('diagnostic', 15.007766559414181),
#  ('discuter', 15.007766559414181),
#  ('conjoncture', 15.007766559414181),
#  ('ameliorent', 15.007766559414181),
#  ('electrique', 15.007766559414181),
#  ('distraction', 15.007766559414181),
#  ('ambassades', 15.007766559414181),
#  ('aveugle', 15.007766559414181),
#  ('consul', 15.007766559414181),
#  ('degagees', 15.007766559414181),
#  ('englobera', 15.007766559414181),
#  ('barguigner', 15.007766559414181),
#  ('clientele', 15.007766559414181),
#  ('exorbitant', 15.007766559414181),
#  ('erreurs', 15.007766559414181),
#  ('connaisse', 15.007766559414181),
#  ('cie', 15.007766559414181),
#  ('emportent', 15.007766559414181),
#  ('confortes', 15.007766559414181),
#  ('elevent', 15.007766559414181),
#  ('authenticite', 15.007766559414181),
#  ('desenchantement', 15.007766559414181),
#  ('cordialite', 15.007766559414181),
#  ('imaginee', 15.007766559414181),
#  ('ajout', 15.007766559414181),
#  ('emanent', 15.007766559414181),
#  ('maintenaient', 15.007766559414181),
#  ('cachee', 15.007766559414181),
#  ('demolir', 15.007766559414181),
#  ('confinant', 15.007766559414181),
#  ('inhabituelle', 15.007766559414181),
#  ('apportons', 15.007766559414181),
#  ('melon', 15.007766559414181),
#  ('decrivait', 15.007766559414181),
#  ('cotonniere', 15.007766559414181),
#  ('charriee', 15.007766559414181),
#  ('deplairait', 15.007766559414181),
#  ('abus', 15.00675942062109),
#  ('aboutissement', 14.911384007887756),
#  ('enumerees', 14.878991284999074),
#  ('abces', 14.810235372735374),
#  ('acteurs', 14.78940526731036),
#  ('chante', 14.780051861455824),
#  ('arles', 14.780051861455824),
#  ('cardinales', 14.780051861455824),
#  ('bienveillants', 14.766698293728833),
#  ('agreables', 14.75500788939815),
#  ('assumions', 14.71126603871542),
#  ('delais', 14.688930025916326),
#  ('chantent', 14.688930025916326),
#  ('allant', 14.68417975275643),
#  ('alcool', 14.68032045785019),
#  ('comprehensif', 14.636796264037656),
#  ('beregovoy', 14.62151320432344),
#  ('averties', 14.572745178193172),
#  ('attendront', 14.55813349172173),
#  ('avancees', 14.543553231727667),
#  ('altruisme', 14.543553231727667),
#  ('banalite', 14.543553231727667),
#  ('accueillir', 14.529004296932877),
#  ('demeurent', 14.514486586493984),
#  ('enseignement', 14.514486586493984),
#  ('collective', 14.514486586493984),
#  ('discriminatoires', 14.514486586493984),
#  ('depensent', 14.514486586493984),
#  ('cheminent', 14.514486586493984),
#  ('democrate', 14.514486586493984),
#  ('creole', 14.514486586493984),
#  ('appretiez', 14.514486586493984),
#  ('concordat', 14.514486586493984),
#  ('affiche', 14.514486586493984),
#  ('addis', 14.507847082494965),
#  ('competitions', 14.478891827572864),
#  ('breviaire', 14.442140771185985),
#  ('beaune', 14.435757171447632),
#  ('atteint', 14.397214484679663),
#  ('correziens', 14.354559253637408),
#  ('cameroun', 14.354559253637408),
#  ('carburants', 14.354559253637408),
#  ('actee', 14.348009548154273),
#  ('competent', 14.335004611030435),
#  ('commerce', 14.306069042316258),
#  ('decision', 14.277975330592287),
#  ('amarante', 14.277975330592287),
#  ('collaborent', 14.277975330592287),
#  ('amicaux', 14.208164930104937),
#  ('afghane', 14.17328613055841),
#  ('alignes', 14.172949084561964),
#  ('beton', 14.172949084561964),
#  ('brouilles', 14.088047037808868),
#  ('balzac', 14.074423791821559),
#  ('ameliore', 14.033723688111476),
#  ('allonger', 14.033723688111476),
#  ('choisie', 14.026964960367433),
#  ('arrivons', 14.026964960367433),
#  ('emission', 14.02021323856064),
#  ('comprehensive', 14.02021323856064),
#  ('decideur', 14.02021323856064),
#  ('departements', 14.013468511803445),
#  ('potentialites', 14.013468511803445),
#  ('argentine', 14.013468511803445),
#  ('greves', 14.013468511803445),
#  ('chaos', 14.013468511803445),
#  ('austro', 14.013468511803445),
#  ('devitalise', 14.013468511803445),
#  ('azur', 14.013468511803445),
#  ('huile', 14.013468511803445),
#  ('divisait', 14.013468511803445),
#  ('becquerel', 14.013468511803445),
#  ('discours', 14.006730769230767),
#  ('appreciation', 14.006730769230767),
#  ('armenie', 14.006730769230767),
#  ('extremes', 14.006730769230767),
#  ('entrepris', 14.006730769230767),
#  ('compare', 14.006730769230767),
#  ('antananarivo', 14.006730769230767),
#  ('familiale', 14.006730769230767),
#  ('federations', 14.006730769230767),
#  ('emprunts', 14.006730769230767),
#  ('evoquait', 14.006730769230767),
#  ('deportation', 14.006730769230767),
#  ('contemporains', 14.006730769230767),
#  ('hesitations', 14.006730769230767),
#  ('croisement', 14.006730769230767),
#  ('heurts', 14.006730769230767),
#  ('blesse', 14.006730769230767),
#  ('environnementaux', 14.006730769230767),
#  ('exporte', 14.006730769230767),
#  ('barbie', 14.006730769230767),
#  ('egalisation', 14.006730769230767),
#  ('devrez', 14.006730769230767),
#  ('entreprenantes', 14.006730769230767),
#  ('avouer', 14.006730769230767),
#  ('batonnier', 14.006730769230767),
#  ('deperit', 14.006730769230767),
#  ('gerent', 14.006730769230767),
#  ('disputaient', 14.006730769230767),
#  ('decorerai', 14.006730769230767),
#  ('dixiemes', 14.006730769230767),
#  ('impairs', 14.006730769230767),
#  ('creerent', 14.006730769230767),
#  ('hallebardiers', 14.006730769230767),
#  ('attende', 14.006730769230767),
#  ('dissimulaient', 14.006730769230767),
#  ('declarations', 14.006730769230767),
#  ('claniques', 14.006730769230767),
#  ('domptant', 14.006730769230767),
#  ('coentreprises', 14.006730769230767),
#  ('attelez', 13.92804253423895),
#  ('banquier', 13.903407013285712),
#  ('consulter', 13.872826369063068),
#  ('aout', 13.832729294052251),
#  ('attentat', 13.828238313064823),
#  ('belgique', 13.802052404988126),
#  ('agilite', 13.779464586373331),
#  ('abominable', 13.775973184192008),
#  ('attribuee', 13.775973184192008),
#  ('citer', 13.685891977936551),
#  ('bois', 13.685891977936551),
#  ('balte', 13.685891977936551),
#  ('attentatoire', 13.669824692279),
#  ('acquises', 13.663660004457984),
#  ('alliances', 13.66034204033013),
#  ('academique', 13.640279335017754),
#  ('competences', 13.631749796190618),
#  ('amoncelaient', 13.631749796190618),
#  ('annales', 13.620564716926053),
#  ('beneficiaires', 13.612431308480618),
#  ('abolissent', 13.605521193054383),
#  ('consolidation', 13.537537537537537),
#  ('accusent', 13.517485553696044),
#  ('devront', 13.51248751248751),
#  ('ebranlees', 13.51248751248751),
#  ('bleriot', 13.51248751248751),
#  ('autoritairement', 13.51248751248751),
#  ('cicatrisees', 13.51248751248751),
#  ('consideraient', 13.51248751248751),
#  ('narrait', 13.51248751248751),
#  ('archeologique', 13.471905468418822),
#  ('argumentation', 13.471905468418822),
#  ('carpates', 13.471905468418822),
#  ('confectionnees', 13.461723625557205),
#  ('boissons', 13.424138122982152),
#  ('compensees', 13.424138122982152),
#  ('chacune', 13.36991176688663),
#  ('agreee', 13.368485217921366),
#  ('courage', 13.351595469016067),
#  ('asperites', 13.351595469016067),
#  ('contructeurs', 13.351595469016067),
#  ('attention', 13.32809295967191),
#  ('assumez', 13.298185394092325),
#  ('agissements', 13.283300115486346),
#  ('clairs', 13.22983548243664),
#  ('armistice', 13.22983548243664),
#  ('boursiere', 13.184291118717347),
#  ('africaine', 13.178525112864065),
#  ('ambiant', 13.122325529293157),
#  ('auditeurs', 13.04630797773655),
#  ('ampere', 13.034697508896798),
#  ('allegement', 13.02890066323317),
#  ('calculer', 13.02890066323317),
#  ('apartheid', 13.023109399303754),
#  ('consistoire', 13.023109399303754),
#  ('cavalerie', 13.023109399303754),
#  ('demagogiques', 13.017323709050528),
#  ('affirmions', 13.017323709050528),
#  ('centralises', 13.017323709050528),
#  ('cran', 13.017323709050528),
#  ('battant', 13.01154358443096),
#  ('centrafricaine', 13.01154358443096),
#  ('conscientes', 13.01154358443096),
#  ('arcole', 13.01154358443096),
#  ('cherte', 13.01154358443096),
#  ('devoye', 13.01154358443096),
#  ('consacrait', 13.01154358443096),
#  ('desordonnees', 13.01154358443096),
#  ('desenclavement', 13.005769017417997),
#  ('couts', 13.005769017417997),
#  ('concues', 13.005769017417997),
#  ('cohesion', 13.005769017417997),
#  ('equipes', 13.005769017417997),
#  ('ecoles', 13.005769017417997),
#  ('consacrer', 13.005769017417997),
#  ('attachent', 13.005769017417997),
#  ...]

# %%
def get_doc_freq_word(self, text : tuple, n : int = 100) -> list :
    """
    Return the list of n words the most frequent
    """
    vectorizer = CountVectorizer()
    corpus = [line for line,pol in text]
    X = vectorizer.fit_transform(corpus)
    words_freq = [(word, (np.transpose(X)[idx]!=0).sum(axis=1)[0,0]) for word, idx in vectorizer.vocabulary_.items()]
    words_freq = sorted(words_freq, key = lambda x: x[1], reverse=True)
    return [w for w,f in words_freq[:n]]

# %%
vectorizer = CountVectorizer()
corpus = [line for line,pol in p_train]
X = vectorizer.fit_transform(corpus)
words_freq = [(word, (np.transpose(X)[idx]!=0).sum(axis=1)[0,0]) for word, idx in vectorizer.vocabulary_.items()]
words_freq = sorted(words_freq, key = lambda x: x[1], reverse=True)
words_freq #lent
# Out:
# [('de', 35268),
#  ('la', 27664),
#  ('et', 26298),
#  ('le', 19625),
#  ('les', 18229),
#  ('des', 16088),
#  ('est', 14927),
#  ('en', 13349),
#  ('que', 13140),
#  ('qui', 12395),
#  ('un', 10791),
#  ('une', 10692),
#  ('dans', 10113),
#  ('pour', 9892),
#  ('du', 8966),
#  ('il', 8861),
#  ('je', 8808),
#  ('nous', 7696),
#  ('au', 7269),
#  ('vous', 7140),
#  ('ce', 6990),
#  ('plus', 5882),
#  ('pas', 5704),
#  ('qu', 5551),
#  ('sur', 5223),
#  ('notre', 5063),
#  ('france', 4937),
#  ('ne', 4890),
#  ('par', 4849),
#  ('cette', 4558),
#  ('mais', 4388),
#  ('avec', 4345),
#  ('aussi', 4232),
#  ('se', 4163),
#  ('nos', 4138),
#  ('pays', 4126),
#  ('ou', 4122),
#  ('sont', 4104),
#  ('elle', 3848),
#  ('ont', 3641),
#  ('aux', 3615),
#  ('etre', 3608),
#  ('tout', 3453),
#  ('tous', 3247),
#  ('votre', 3059),
#  ('leur', 2994),
#  ('son', 2834),
#  ('bien', 2821),
#  ('nom', 2755),
#  ('ces', 2712),
#  ('meme', 2692),
#  ('comme', 2642),
#  ('hui', 2558),
#  ('aujourd', 2557),
#  ('on', 2497),
#  ('entre', 2476),
#  ('doit', 2389),
#  ('europe', 2382),
#  ('monde', 2365),
#  ('faire', 2327),
#  ('ses', 2322),
#  ('sa', 2286),
#  ('francais', 2282),
#  ('ai', 2147),
#  ('faut', 2015),
#  ('ils', 2006),
#  ('si', 1991),
#  ('ete', 1974),
#  ('sans', 1928),
#  ('fait', 1898),
#  ('etat', 1847),
#  ('date', 1740),
#  ('cela', 1695),
#  ('dire', 1635),
#  ('ensemble', 1628),
#  ('avez', 1625),
#  ('peut', 1582),
#  ('deux', 1581),
#  ('developpement', 1576),
#  ('dont', 1565),
#  ('tres', 1563),
#  ('leurs', 1522),
#  ('encore', 1480),
#  ('politique', 1475),
#  ('autres', 1471),
#  ('president', 1466),
#  ('monsieur', 1449),
#  ('toutes', 1413),
#  ('vie', 1389),
#  ('avons', 1386),
#  ('vos', 1344),
#  ('ici', 1322),
#  ('ceux', 1298),
#  ('depuis', 1283),
#  ('temps', 1279),
#  ('toute', 1203),
#  ('chacun', 1193),
#  ('avenir', 1190),
#  ('paix', 1190),
#  ('union', 1189),
#  ('europeenne', 1164),
#  ('abord', 1162),
#  ('notamment', 1151),
#  ('ans', 1123),
#  ('economique', 1123),
#  ('beaucoup', 1122),
#  ('me', 1114),
#  ('place', 1100),
#  ('toujours', 1092),
#  ('suis', 1087),
#  ('elles', 1077),
#  ('securite', 1069),
#  ('grande', 1058),
#  ('histoire', 1057),
#  ('lui', 1041),
#  ('cet', 1034),
#  ('enfin', 1026),
#  ('societe', 1023),
#  ('devons', 1014),
#  ('premier', 1005),
#  ('grand', 983),
#  ('entreprises', 981),
#  ('soit', 965),
#  ('parce', 957),
#  ('ainsi', 955),
#  ('autre', 952),
#  ('mon', 944),
#  ('souhaite', 944),
#  ('action', 943),
#  ('etait', 942),
#  ('fois', 920),
#  ('doivent', 919),
#  ('mieux', 914),
#  ('sera', 909),
#  ('contre', 895),
#  ('hommes', 886),
#  ('travail', 879),
#  ('chaque', 879),
#  ('deja', 866),
#  ('volonte', 866),
#  ('egalement', 862),
#  ('droit', 843),
#  ('annees', 838),
#  ('solidarite', 833),
#  ('dialogue', 832),
#  ('respect', 827),
#  ('avoir', 819),
#  ('jeunes', 819),
#  ('alors', 818),
#  ('coeur', 812),
#  ('democratie', 812),
#  ('moyens', 806),
#  ('souvent', 799),
#  ('donc', 798),
#  ('republique', 792),
#  ('confiance', 791),
#  ('progres', 790),
#  ('gouvernement', 790),
#  ('car', 789),
#  ('esprit', 782),
#  ('part', 781),
#  ('moi', 768),
#  ('liberte', 760),
#  ('service', 760),
#  ('homme', 757),
#  ('nouvelle', 754),
#  ('quelques', 744),
#  ('celle', 740),
#  ('francaise', 738),
#  ('voudrais', 734),
#  ('etats', 734),
#  ('naturellement', 733),
#  ('donner', 713),
#  ('grands', 710),
#  ('apres', 708),
#  ('cooperation', 708),
#  ('communaute', 697),
#  ('role', 697),
#  ('force', 696),
#  ('ma', 691),
#  ('celui', 690),
#  ('non', 685),
#  ('sommes', 679),
#  ('premiere', 673),
#  ('nouvelles', 669),
#  ('sociale', 665),
#  ('annee', 664),
#  ('messieurs', 659),
#  ('sais', 657),
#  ('conseil', 654),
#  ('jamais', 650),
#  ('sous', 648),
#  ('peu', 647),
#  ('pense', 643),
#  ('oeuvre', 643),
#  ('emploi', 634),
#  ('culture', 629),
#  ('ailleurs', 626),
#  ('tant', 626),
#  ('nouveau', 623),
#  ('valeurs', 622),
#  ('mes', 621),
#  ('general', 613),
#  ('afrique', 612),
#  ('grandes', 611),
#  ('internationale', 606),
#  ('nation', 605),
#  ('mesdames', 603),
#  ('nationale', 602),
#  ('peuples', 600),
#  ('amitie', 596),
#  ('dit', 596),
#  ('avant', 595),
#  ('eux', 588),
#  ('croissance', 588),
#  ('trop', 584),
#  ('droits', 584),
#  ('quand', 583),
#  ('sens', 582),
#  ('compte', 572),
#  ('social', 569),
#  ('vers', 568),
#  ('domaine', 568),
#  ('qualite', 566),
#  ('besoin', 565),
#  ('responsabilite', 565),
#  ('heure', 561),
#  ('region', 560),
#  ('relations', 558),
#  ('nations', 557),
#  ('economie', 557),
#  ('pourquoi', 556),
#  ('peuple', 556),
#  ('passe', 553),
#  ('prendre', 543),
#  ('moment', 543),
#  ('efforts', 542),
#  ('loi', 537),
#  ('soient', 536),
#  ('demain', 532),
#  ('cadre', 532),
#  ('etes', 528),
#  ('paris', 525),
#  ('mettre', 522),
#  ('effort', 519),
#  ('partenaires', 518),
#  ('necessaire', 517),
#  ('femmes', 516),
#  ('environnement', 515),
#  ('dela', 515),
#  ('jour', 513),
#  ('celles', 510),
#  ('ambition', 506),
#  ('veux', 506),
#  ('pouvoir', 504),
#  ('entreprise', 504),
#  ('choix', 503),
#  ('siecle', 502),
#  ('moins', 502),
#  ('forte', 500),
#  ('creation', 499),
#  ('vrai', 499),
#  ('voie', 497),
#  ('crois', 495),
#  ('avait', 493),
#  ('aide', 492),
#  ('rendre', 490),
#  ('desormais', 490),
#  ('formation', 490),
#  ('cours', 487),
#  ('recherche', 486),
#  ('ville', 485),
#  ('va', 484),
#  ('vivre', 483),
#  ('essentiel', 481),
#  ('plan', 481),
#  ('ministre', 480),
#  ('politiques', 479),
#  ('seulement', 478),
#  ('nombre', 477),
#  ('conditions', 477),
#  ('systeme', 477),
#  ('longtemps', 477),
#  ('memes', 477),
#  ('devant', 476),
#  ('organisation', 476),
#  ('echanges', 475),
#  ('europeen', 474),
#  ('projet', 474),
#  ('succes', 473),
#  ('cas', 473),
#  ('heureux', 472),
#  ('publics', 472),
#  ('occasion', 470),
#  ('exemple', 470),
#  ('enfants', 469),
#  ('engagement', 467),
#  ('autant', 465),
#  ('nouveaux', 465),
#  ('economiques', 464),
#  ('particulier', 460),
#  ('reste', 457),
#  ('interet', 456),
#  ('peuvent', 454),
#  ('face', 450),
#  ('donne', 449),
#  ('famille', 447),
#  ('assurer', 443),
#  ('possible', 442),
#  ('trois', 437),
#  ('situation', 437),
#  ('services', 437),
#  ('reforme', 435),
#  ('mise', 432),
#  ('institutions', 431),
#  ('effet', 430),
#  ('point', 428),
#  ('parmi', 427),
#  ('saluer', 423),
#  ('laquelle', 423),
#  ('problemes', 421),
#  ('forces', 420),
#  ('capacite', 418),
#  ('sommet', 417),
#  ('mesure', 416),
#  ('nombreux', 416),
#  ('davantage', 416),
#  ('facon', 414),
#  ('surtout', 413),
#  ('niveau', 413),
#  ('serait', 413),
#  ('agit', 407),
#  ('particulierement', 407),
#  ('sein', 407),
#  ('doute', 405),
#  ('sante', 404),
#  ('honneur', 403),
#  ('parfois', 403),
#  ('accord', 402),
#  ('maire', 401),
#  ('savoir', 399),
#  ('su', 399),
#  ('comment', 397),
#  ('puis', 397),
#  ('maintenant', 396),
#  ('grace', 395),
#  ('lieu', 395),
#  ('difficultes', 393),
#  ('initiative', 393),
#  ('developper', 392),
#  ('savez', 391),
#  ('eu', 389),
#  ('commun', 386),
#  ('commune', 386),
#  ('seront', 386),
#  ('loin', 383),
#  ('rien', 380),
#  ('ecole', 380),
#  ('amerique', 379),
#  ('publique', 378),
#  ('lors', 377),
#  ('domaines', 377),
#  ('voila', 376),
#  ('responsabilites', 376),
#  ('juste', 375),
#  ('mer', 374),
#  ('sud', 373),
#  ('continent', 370),
#  ('europeens', 370),
#  ('certains', 368),
#  ('renforcer', 366),
#  ('guerre', 365),
#  ('defense', 365),
#  ('justice', 364),
#  ('pris', 363),
#  ('projets', 363),
#  ('lutte', 363),
#  ('diversite', 363),
#  ('public', 363),
#  ('raison', 362),
#  ('necessaires', 362),
#  ('marche', 362),
#  ('mois', 361),
#  ('realite', 360),
#  ('mondiale', 359),
#  ('font', 354),
#  ('combat', 354),
#  ('pleinement', 353),
#  ('evolution', 352),
#  ('equilibre', 351),
#  ('national', 350),
#  ('aller', 349),
#  ('veritable', 349),
#  ('creer', 349),
#  ('fut', 347),
#  ('activite', 346),
#  ('pu', 346),
#  ('principes', 346),
#  ('bonne', 345),
#  ('protection', 345),
#  ('compatriotes', 345),
#  ('presence', 345),
#  ('ordre', 345),
#  ('voir', 344),
#  ('efficacite', 344),
#  ('liens', 342),
#  ('chemin', 342),
#  ('dernier', 341),
#  ('partenariat', 340),
#  ('travers', 339),
#  ('repondre', 338),
#  ('permettre', 337),
#  ('mondialisation', 337),
#  ('relation', 333),
#  ('outre', 333),
#  ('porte', 329),
#  ('question', 328),
#  ('objectif', 327),
#  ('demande', 327),
#  ('partout', 325),
#  ('moderne', 324),
#  ('mission', 322),
#  ('fort', 321),
#  ('personnes', 318),
#  ('regles', 318),
#  ('plusieurs', 318),
#  ('sociaux', 318),
#  ('engage', 317),
#  ('sorte', 317),
#  ('mouvement', 316),
#  ('important', 314),
#  ('trouver', 314),
#  ('hommage', 312),
#  ('cause', 312),
#  ('concitoyens', 311),
#  ('francaises', 310),
#  ('international', 309),
#  ('ouverture', 308),
#  ('chez', 307),
#  ('veut', 307),
#  ('reconnaissance', 307),
#  ('long', 306),
#  ('emplois', 306),
#  ('cotes', 305),
#  ('idee', 304),
#  ('conscience', 304),
#  ('simplement', 304),
#  ('terme', 304),
#  ('construire', 303),
#  ('fin', 303),
#  ('egalite', 303),
#  ('citoyens', 303),
#  ('amis', 302),
#  ('besoins', 302),
#  ('cher', 301),
#  ('partie', 301),
#  ('membres', 299),
#  ('euro', 299),
#  ('cultures', 299),
#  ('familles', 299),
#  ('construction', 299),
#  ('vision', 298),
#  ('accueil', 297),
#  ('entendu', 297),
#  ('unis', 297),
#  ('afin', 296),
#  ('importance', 295),
#  ('prix', 295),
#  ('mis', 294),
#  ('aucun', 293),
#  ('terre', 293),
#  ('cesse', 292),
#  ('responsables', 292),
#  ('sait', 292),
#  ('interets', 291),
#  ('voulu', 291),
#  ('autorite', 290),
#  ('identite', 290),
#  ('indispensable', 290),
#  ('estime', 289),
#  ('choses', 289),
#  ('chefs', 289),
#  ('combien', 289),
#  ('permis', 288),
#  ('necessite', 288),
#  ('reformes', 288),
#  ('pendant', 287),
#  ('devoir', 287),
#  ('parle', 287),
#  ('soutien', 286),
#  ('collectivites', 286),
#  ('pres', 285),
#  ('meilleur', 285),
#  ('propose', 284),
#  ('exigence', 284),
#  ('vocation', 282),
#  ('etaient', 281),
#  ('dignite', 281),
#  ('visite', 281),
#  ('seul', 280),
#  ('matiere', 280),
#  ('langue', 280),
#  ('puissance', 280),
#  ('aura', 279),
#  ('exprimer', 278),
#  ('tiens', 277),
#  ('destin', 277),
#  ('jusqu', 276),
#  ('titre', 274),
#  ('territoire', 274),
#  ('cote', 273),
#  ('egard', 273),
#  ('dynamisme', 272),
#  ('conference', 271),
#  ('pourrait', 271),
#  ('education', 271),
#  ('cohesion', 271),
#  ('chomage', 270),
#  ('experience', 270),
#  ('stabilite', 268),
#  ('determination', 267),
#  ('travaux', 266),
#  ('principe', 266),
#  ('trouve', 265),
#  ('agir', 265),
#  ('pouvoirs', 265),
#  ('remercie', 264),
#  ('reussite', 264),
#  ('rencontre', 263),
#  ('quelque', 261),
#  ('cinq', 260),
#  ('crise', 260),
#  ('nature', 260),
#  ('millions', 259),
#  ('ressources', 258),
#  ('lorsque', 258),
#  ('elus', 258),
#  ('marque', 257),
#  ('difficile', 257),
#  ('soir', 257),
#  ('violence', 257),
#  ('charge', 256),
#  ('message', 256),
#  ('bon', 255),
#  ('certain', 255),
#  ('an', 255),
#  ('technologies', 255),
#  ('vient', 254),
#  ('acces', 254),
#  ('constitue', 253),
#  ('deuxieme', 252),
#  ('unies', 252),
#  ('aider', 252),
#  ('courage', 251),
#  ('modele', 251),
#  ('reflexion', 251),
#  ('questions', 250),
#  ('regions', 249),
#  ('espace', 248),
#  ('venu', 248),
#  ('salue', 248),
#  ('propre', 247),
#  ('debat', 247),
#  ('allemagne', 246),
#  ('objectifs', 246),
#  ('maniere', 246),
#  ('initiatives', 245),
#  ('quatre', 245),
#  ('mot', 245),
#  ('appelle', 245),
#  ('venir', 244),
#  ('franco', 244),
#  ('secteur', 244),
#  ('personne', 243),
#  ('locales', 243),
#  ('apporter', 242),
#  ('asie', 242),
#  ('ni', 241),
#  ('premiers', 240),
#  ('sentiment', 239),
#  ('representants', 239),
#  ('professionnelle', 239),
#  ('partage', 238),
#  ('acteurs', 238),
#  ('haut', 237),
#  ('parler', 237),
#  ('culturelle', 236),
#  ('prochain', 236),
#  ('engager', 236),
#  ('avais', 236),
#  ('risques', 236),
#  ('hier', 235),
#  ('probleme', 235),
#  ('processus', 235),
#  ('evoque', 233),
#  ('espoir', 233),
#  ('humaine', 233),
#  ('longue', 233),
#  ('devra', 233),
#  ('dernieres', 232),
#  ('faveur', 232),
#  ('autour', 232),
#  ('lequel', 231),
#  ('decisions', 231),
#  ('retrouver', 230),
#  ('conviction', 230),
#  ('commerce', 230),
#  ('quel', 230),
#  ('richesse', 229),
#  ('priorite', 228),
#  ('chance', 228),
#  ('lorsqu', 228),
#  ('democratique', 228),
#  ('nord', 226),
#  ('societes', 226),
#  ('jeunesse', 226),
#  ('tradition', 226),
#  ('forme', 225),
#  ('affaires', 225),
#  ('permet', 225),
#  ('dix', 224),
#  ('unite', 224),
#  ('exprime', 224),
#  ('defendre', 224),
#  ('profondement', 223),
#  ('remercier', 223),
#  ('parlement', 222),
#  ('energie', 219),
#  ('unique', 219),
#  ('cite', 219),
#  ('decide', 218),
#  ('efficace', 218),
#  ('reunion', 217),
#  ('mesures', 217),
#  ('pourtant', 217),
#  ('ami', 216),
#  ('comprendre', 216),
#  ('seule', 216),
#  ('memoire', 216),
#  ('ouvert', 216),
#  ('meilleure', 216),
#  ('siecles', 215),
#  ('prise', 215),
#  ('oui', 214),
#  ('ensuite', 214),
#  ('humanite', 214),
#  ('jouer', 213),
#  ('enseignement', 213),
#  ('risque', 212),
#  ('chances', 212),
#  ('culturel', 211),
#  ('associations', 210),
#  ('travailler', 210),
#  ('lois', 210),
#  ('frontieres', 209),
#  ('apporte', 209),
#  ('image', 209),
#  ('gestion', 209),
#  ('plaisir', 208),
#  ('jours', 206),
#  ('importante', 206),
#  ('adapter', 206),
#  ('exclusion', 206),
#  ('chacune', 205),
#  ('compris', 205),
#  ('dynamique', 205),
#  ('belle', 204),
#  ('demarche', 204),
#  ('sociales', 204),
#  ('montre', 203),
#  ('traditions', 202),
#  ('population', 202),
#  ('commission', 202),
#  ('libre', 201),
#  ('rejouis', 201),
#  ('entiere', 201),
#  ('ci', 200),
#  ('presidence', 200),
#  ('premieres', 200),
#  ('chef', 200),
#  ('vu', 200),
#  ('poursuivre', 200),
#  ('signe', 199),
#  ('instant', 199),
#  ('consequences', 199),
#  ('chers', 198),
#  ('internationales', 198),
#  ('impose', 198),
#  ('ameliorer', 197),
#  ('proche', 197),
#  ('administration', 197),
#  ('vont', 197),
#  ('dis', 196),
#  ('expression', 196),
#  ('generations', 196),
#  ('avaient', 196),
#  ('emotion', 196),
#  ('vingt', 196),
#  ('investissements', 196),
#  ('communes', 196),
#  ('ait', 195),
#  ('etape', 195),
#  ('ouvrir', 195),
#  ('actions', 195),
#  ('puisse', 195),
#  ('valeur', 194),
#  ('durable', 194),
#  ('information', 194),
#  ('traite', 193),
#  ('decision', 192),
#  ('nombreuses', 192),
#  ('marches', 192),
#  ('rang', 191),
#  ('association', 191),
#  ('viennent', 191),
#  ('ethique', 191),
#  ('mondial', 190),
#  ('habitants', 189),
#  ('militaire', 189),
#  ('origine', 188),
#  ('independance', 188),
#  ('formes', 188),
#  ('permettra', 187),
#  ('rapport', 187),
#  ('vue', 187),
#  ('modernisation', 187),
#  ('progresser', 186),
#  ('chose', 186),
#  ('impulsion', 186),
#  ('tel', 186),
#  ('fraternite', 186),
#  ('telle', 186),
#  ('produits', 186),
#  ('publiques', 186),
#  ('missions', 186),
#  ('auquel', 186),
#  ('soi', 185),
#  ('moyen', 185),
#  ('alliance', 185),
#  ('charges', 185),
#  ('pouvons', 184),
#  ('large', 184),
#  ('certaines', 184),
#  ('armees', 184),
#  ('scientifique', 184),
#  ('merci', 183),
#  ('rapidement', 183),
#  ('defi', 183),
#  ('concerne', 183),
#  ('voeux', 183),
#  ('existe', 182),
#  ('departement', 182),
#  ('mal', 182),
#  ('debut', 182),
#  ('represente', 181),
#  ('terrain', 181),
#  ('ministres', 180),
#  ('prosperite', 180),
#  ('voulons', 180),
#  ('exigences', 180),
#  ('temoigne', 180),
#  ('francophonie', 180),
#  ('corps', 180),
#  ('garde', 179),
#  ('monnaie', 179),
#  ('condition', 179),
#  ('souci', 178),
#  ('soins', 178),
#  ('immense', 178),
#  ('chine', 178),
#  ('dimension', 177),
#  ('porter', 177),
#  ('activites', 177),
#  ('engagee', 177),
#  ('industrie', 176),
#  ('cree', 176),
#  ('negociation', 176),
#  ('centre', 175),
#  ('exemplaire', 175),
#  ('preserver', 175),
#  ('assemblee', 175),
#  ('certaine', 174),
#  ('partir', 174),
#  ('malgre', 174),
#  ('etranger', 174),
#  ('essentielle', 173),
#  ('patrimoine', 173),
#  ('integration', 173),
#  ('latine', 173),
#  ('techniques', 173),
#  ('fonds', 173),
#  ('quelle', 172),
#  ('libertes', 172),
#  ('savons', 171),
#  ('solutions', 171),
#  ('puisque', 170),
#  ('connaitre', 170),
#  ('resultats', 170),
#  ('vite', 170),
#  ('attentes', 170),
#  ('conflits', 170),
#  ('historique', 170),
#  ('elargissement', 170),
#  ('civilisation', 170),
#  ('aucune', 170),
#  ('presente', 169),
#  ('lien', 169),
#  ('parents', 169),
#  ('faudra', 169),
#  ('programme', 169),
#  ('mobiliser', 169),
#  ('art', 168),
#  ('saint', 168),
#  ('prises', 168),
#  ('engagements', 168),
#  ('base', 167),
#  ('commence', 167),
#  ('heures', 166),
#  ('tenu', 166),
#  ('conduit', 166),
#  ('renforcement', 165),
#  ('evidemment', 165),
#  ('departements', 165),
#  ('energies', 165),
#  ('periode', 165),
#  ('concertation', 165),
#  ('garantir', 165),
#  ('assumer', 164),
#  ('villes', 164),
#  ('personnel', 164),
#  ('main', 164),
#  ('tirer', 164),
#  ('production', 164),
#  ('conduire', 164),
#  ('jeune', 164),
#  ('assez', 163),
#  ('recemment', 163),
#  ('devenir', 163),
#  ('largement', 163),
#  ('agisse', 162),
#  ('nouvel', 162),
#  ('defis', 162),
#  ('riche', 161),
#  ('contribuer', 161),
#  ('negociations', 161),
#  ('veulent', 161),
#  ('epoque', 160),
#  ('maladie', 160),
#  ('accords', 160),
#  ('revient', 160),
#  ('revolution', 160),
#  ('affirmer', 160),
#  ('entier', 159),
#  ('raisons', 159),
#  ('certes', 159),
#  ('mobilisation', 159),
#  ('connu', 157),
#  ('science', 157),
#  ('uns', 157),
#  ('competences', 157),
#  ('pourra', 157),
#  ('preparer', 156),
#  ('accompagner', 156),
#  ('contribue', 156),
#  ('particuliere', 156),
#  ('organiser', 155),
#  ('evolutions', 155),
#  ('elan', 155),
#  ('reponse', 155),
#  ('contraire', 155),
#  ('puissent', 155),
#  ('etudiants', 155),
#  ('exercice', 155),
#  ('pauvres', 154),
#  ('japon', 154),
#  ('planete', 154),
#  ('voyage', 154),
#  ('eau', 154),
#  ('preuve', 154),
#  ('encourager', 154),
#  ('proximite', 154),
#  ('connaissance', 154),
#  ('permettez', 153),
#  ('enfant', 153),
#  ('joie', 153),
#  ('pacte', 153),
#  ('compter', 153),
#  ('liban', 153),
#  ('agriculture', 153),
#  ('reussir', 152),
#  ('propositions', 152),
#  ('autorites', 151),
#  ('orient', 151),
#  ('vraiment', 151),
#  ('appel', 151),
#  ('constitution', 151),
#  ('rappeler', 150),
#  ('fonction', 150),
#  ('connait', 150),
#  ('competence', 149),
#  ('repete', 149),
#  ('fonde', 149),
#  ('attachement', 149),
#  ('voix', 148),
#  ('attention', 148),
#  ('tache', 148),
#  ('troisieme', 148),
#  ('aupres', 148),
#  ('civilisations', 147),
#  ('portee', 147),
#  ('retour', 147),
#  ('souvenir', 147),
#  ('respecter', 147),
#  ('rester', 146),
#  ('ceci', 146),
#  ('capacites', 146),
#  ('caractere', 146),
#  ('participer', 146),
#  ('preoccupations', 146),
#  ('attache', 146),
#  ('atouts', 146),
#  ('auxquels', 146),
#  ('professionnels', 146),
#  ('regionale', 145),
#  ('accueillir', 145),
#  ('enjeu', 145),
#  ('joue', 144),
#  ('reconnaitre', 144),
#  ('populations', 144),
#  ('idees', 144),
#  ('prevention', 144),
#  ('realites', 144),
#  ('universite', 143),
#  ('terrorisme', 143),
#  ('langues', 143),
#  ('secteurs', 143),
#  ('armes', 143),
#  ('rencontrer', 143),
#  ('veiller', 143),
#  ('innovation', 143),
#  ('relever', 143),
#  ('tolerance', 142),
#  ('groupe', 142),
#  ('menace', 142),
#  ('engages', 141),
#  ('acquis', 141),
#  ('petites', 141),
#  ('statut', 141),
#  ('armee', 141),
#  ('voit', 141),
#  ('humain', 141),
#  ('contrat', 141),
#  ('appartient', 140),
#  ('tour', 140),
#  ('sujet', 140),
#  ('present', 140),
#  ('ouverte', 140),
#  ('devrait', 140),
#  ('favoriser', 140),
#  ('devront', 140),
#  ('pensee', 139),
#  ('suite', 139),
#  ('responsable', 139),
#  ('juin', 139),
#  ('suppose', 138),
#  ('tient', 138),
#  ('souligne', 138),
#  ('programmes', 138),
#  ('aurait', 138),
#  ('intelligence', 138),
#  ('eh', 137),
#  ('fonctionnement', 137),
#  ('ideal', 137),
#  ('vais', 137),
#  ('ambitions', 137),
#  ('insecurite', 137),
#  ('madame', 137),
#  ('tenir', 137),
#  ('matin', 136),
#  ('victimes', 136),
#  ('invite', 136),
#  ('militaires', 136),
#  ('offre', 135),
#  ('salaries', 135),
#  ('reduire', 135),
#  ('richesses', 135),
#  ('faites', 135),
#  ('collective', 135),
#  ('laisser', 135),
#  ('solution', 134),
#  ('evoquer', 134),
#  ('dirigeants', 134),
#  ('realisation', 134),
#  ('formidable', 134),
#  ('touche', 134),
#  ('interieur', 134),
#  ('profonde', 134),
#  ('adhesion', 134),
#  ('contraintes', 134),
#  ('mener', 134),
#  ...]

# %% [markdown]
# Question qui devient de plus en plus intéressante avec les approches modernes:
# est-il possible d'extraire des tri-grammes de lettres pour représenter nos documents?
#
# Quelle performances attendrent? Quels sont les avantages et les inconvénients d'une telle approche?

# %%
extractor = voc_extracting()

# President
print("Size Voc :")
print(extractor.get_size(p_train))

# print("World Cloud :")
# print(extractor.word_cloud(p_train))

print("Most frequent words (100)")
print(extractor.get_most_freq_word(p_train, 100)) # Beaucoup de stop word, premier mot intéressant à l'index 35 -> france

print("TF-IDF (100) :")
print(extractor.get_tf_idf(p_train, 100)) # le mot france est mieux classé, diminution de l'influence des stop word

# print("ODD (100) :")
# print(extractor.get_odd(p_train, 100))

# print("Zipf (100) :")
# print(extractor.get_zipf_distribution(p_train, 100)) # le mot france est mieux classé mais moins bien que TF-IFD
# Out:
# Size Voc :
# C:\Anaconda\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# 27054
# Most frequent words (100)
# ['de', 'la', 'et', 'le', 'les', 'des', 'est', 'en', 'que', 'qui', 'un', 'une', 'pour', 'dans', 'du', 'je', 'il', 'nous', 'vous', 'au', 'ce', 'plus', 'qu', 'pas', 'sur', 'notre', 'par', 'ne', 'france', 'nos', 'avec', 'cette', 'ou', 'se', 'mais', 'pays', 'sont', 'elle', 'aussi', 'aux', 'ont', 'etre', 'leur', 'tout', 'votre', 'nom', 'tous', 'son', 'on', 'bien', 'ces', 'meme', 'ses', 'comme', 'entre', 'europe', 'sa', 'hui', 'aujourd', 'monde', 'doit', 'faire', 'francais', 'ai', 'ils', 'si', 'faut', 'sans', 'ete', 'fait', 'date', 'etat', 'leurs', 'cela', 'avez', 'dire', 'tres', 'deux', 'ensemble', 'peut', 'developpement', 'dont', 'vos', 'autres', 'president', 'politique', 'monsieur', 'encore', 'toutes', 'vie', 'avons', 'ceux', 'temps', 'ici', 'depuis', 'toute', 'paix', 'union', 'chacun', 'avenir']
# TF-IDF (100) :
# ['de', 'la', 'et', 'le', 'les', 'des', 'est', 'en', 'que', 'qui', 'une', 'un', 'pour', 'dans', 'il', 'nous', 'je', 'vous', 'du', 'ce', 'plus', 'au', 'pas', 'notre', 'sur', 'qu', 'france', 'ne', 'elle', 'nos', 'par', 'cette', 'sont', 'aussi', 'avec', 'mais', 'pays', 'se', 'etre', 'ont', 'votre', 'ou', 'aux', 'leur', 'nom', 'tout', 'tous', 'son', 'bien', 'doit', 'on', 'europe', 'ces', 'meme', 'ses', 'hui', 'aujourd', 'entre', 'sa', 'faut', 'faire', 'comme', 'francais', 'ils', 'monde', 'ai', 'cela', 'fait', 'ete', 'etat', 'sans', 'si', 'date', 'monsieur', 'avez', 'president', 'ensemble', 'deux', 'leurs', 'tres', 'peut', 'avons', 'developpement', 'politique', 'dire', 'vos', 'encore', 'autres', 'avenir', 'temps', 'abord', 'toutes', 'paix', 'vie', 'dont', 'messieurs', 'chacun', 'depuis', 'beaucoup', 'union']

# %% [markdown]
# # Modèles de Machine Learning
#
# Avant de lancer de grandes expériences, il faut se construire une base de travail solide en étudiant les questions suivantes:
#
# - Combien de temps ça prend d'apprendre un classifieur NB/SVM/RegLog sur ces données en fonction de la taille du vocabulaire?
# - La validation croisée est-elle nécessaire? Est ce qu'on obtient les mêmes résultats avec un simple *split*?
# - La validation croisée est-elle stable? A partir de combien de fold (travailler avec différentes graines aléatoires et faire des statistiques basiques)?

# %% [markdown]
# ## Première campagne d'expériences
#
# Les techniques sur lesquelles nous travaillons étant sujettes au sur-apprentissage: trouver le paramètre de régularisation dans la documentation et optimiser ce paramètre au sens de la métrique qui vous semble la plus appropriée (cf question précédente).

# %% [markdown]
# ## Equilibrage des données
#
# Un problème reconnu comme dur dans la communauté est celui de l'équilibrage des classes (*balance* en anglais). Que faire si les données sont à 80, 90 ou 99% dans une des classes?
# Le problème est dur mais fréquent; les solutions sont multiples mais on peut isoler 3 grandes familles de solution.
#
# 1. Ré-équilibrer le jeu de données: supprimer des données dans la classe majoritaire et/ou sur-échantilloner la classe minoritaire.<BR>
#    $\Rightarrow$ A vous de jouer pour cette technique
# 1. Changer la formulation de la fonction de coût pour pénaliser plus les erreurs dans la classe minoritaire:
# soit une fonction $\Delta$ mesurant les écarts entre $f(x_i)$ et $y_i$
# $$C = \sum_i  \alpha_i \Delta(f(x_i),y_i), \qquad \alpha_i = \left\{
# \begin{array}{ll}
# 1 & \text{si } y_i \in \text{classe majoritaire}\\
# B>1 & \text{si } y_i \in \text{classe minoritaire}\\
# \end{array} \right.$$
# <BR>
#    $\Rightarrow$ Les SVM et d'autres approches sklearn possèdent des arguments pour régler $B$ ou $1/B$... Ces arguments sont utiles mais pas toujours suffisant.
# 1. Courbe ROC et modification du biais. Une fois la fonction $\hat y = f(x)$ apprise, il est possible de la *bidouiller* a posteriori: si toutes les prédictions $\hat y$ sont dans une classe, on va introduire $b$ dans $\hat y = f(x) + b$ et le faire varier jusqu'à ce qu'un des points change de classe. On peut ensuite aller de plus en plus loin.
# Le calcul de l'ensemble des scores associés à cette approche mène directement à la courbe ROC.
#
# **Note:** certains classifieurs sont intrinsèquement plus résistante au problème d'équilibrage, c'est par exemple le cas des techniques de gradient boosting que vous verrez l'an prochain.
